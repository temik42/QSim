# %%
# %cd 'Q:\Dropbox\python\QSim\'
# Out:
# Q:\Dropbox\python\QSim

# %%
# %matplotlib inline
from scipy.io import *
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import numpy as np
#from numpy import fft
#from numpy import linalg
#from scipy import interpolate
#from sklearn.cluster import DBSCAN
#from scipy import optimize
from pyfield import *
import time

# %%
s = np.load('data\sdo.x766y1118.20110225.npz')

hmi_data = s['hmi']
aia_data = s['aia_171']

# %%
field = Field(hmi_data[135,:,:],1.).search_charges(25).search_nulls().draw_footprint()
# Out:
# Searching charges...
# Done! Elapsed time: 0.0019998550415
# Searching nulls...
# Done! Elapsed time: 0.831000089645

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.flipud(aia_data[565,:,:])**0.3, 'gray')

# %%
hmi_data.shape
# Out:
# (481, 64, 64)

# %%
aia_data.shape
# Out:
# (1800, 64, 64)

# %%
1800/481.*130
# Out:
# 486.4864864864865

# %%
# ?plt.imshow
