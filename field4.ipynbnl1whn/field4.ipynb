# %%
# %cd 'Q:\Dropbox\python\QSim\'
# Out:
# Q:\Dropbox\python\QSim

# %%
# %matplotlib inline
from scipy.io import *
import matplotlib.pyplot as plt
import numpy as np
from pyfield import *
import time

# %%
s = np.load('data\sdo.x766y1118.20110225.npz')

hmi_data = s['hmi']
aia_data = s['aia_171']

# %%
field = Field(hmi_data[135,:,:],1.).search_charges(25).search_nulls().draw_footprint((8,8))
# Out:
# Searching charges...
# Done! Elapsed time: 0.0019998550415
# Searching nulls...
# Done! Elapsed time: 0.851000070572

# %%
plt.figure(figsize=(8,8))
plt.imshow(np.flipud(aia_data[500,:,:])**0.3, 'gray', interpolation = 'nearest')

# %%
plt.figure(figsize=(16,4))
for i in range(0,8):
    plt.subplot(1,8,i+1)
    plt.imshow(np.flipud(aia_data[500+i,:,:])**0.3, 'gray', interpolation = 'nearest')

# %%
hmi_data.shape
# Out:
# (481, 64, 64)

# %%
aia_data.shape
# Out:
# (1800, 64, 64)

# %%
1800/481.*130
# Out:
# 486.4864864864865

# %%
# ?plt.subplot
