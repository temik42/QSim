# %%
# %cd 'Q:\Dropbox\python\QSim\'
# Out:
# Q:\Dropbox\python\QSim

# %%
from scipy.io import *
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.integrate import ode

# %%
def cross(a, b):
    return [a[i]*b[i+1]-a[i+1]*b[i] for i in [1,-1,0]]

def jacobian(X):
    #J = [[(np.roll(X[i],-1,j)-np.roll(X[i],1,j))*0.5 for j in range(0,3)] for i in range(0,3)]
    J = [np.gradient(X[i], edge_order = 2) for i in range(0,3)]
    #for i in range(0,3):
    #    J[i][0][0,:,:] = -1.5*X[i][0,:,:]+2*X[i][1,:,:]-0.5*X[i][2,:,:]
    #    J[i][0][-1,:,:] = 1.5*X[i][-1,:,:]-2*X[i][-2,:,:]+0.5*X[i][-3,:,:]
    #    J[i][1][:,0,:] = -1.5*X[i][:,0,:]+2*X[i][:,1,:]-0.5*X[i][:,2,:]
    #    J[i][1][:,-1,:] = 1.5*X[i][:,-1,:]-2*X[i][:,-2,:]+0.5*X[i][:,-3,:]
    #    J[i][2][:,:,0] = -1.5*X[i][:,:,0]+2*X[i][:,:,1]-0.5*X[i][:,:,2]
    #    J[i][2][:,:,-1] = 1.5*X[i][:,:,-1]-2*X[i][:,:,-2]+0.5*X[i][:,:,-3]
    return J

def hessian(X):
    J = jacobian(X)   
    H = [[[(-2*X[i] + np.roll(X[i],-1,k)+np.roll(X[i],1,k)) if k == j else 
           (np.roll(J[i][j],-1,k)-np.roll(J[i][j],1,k))*0.5 for k in range(0,j+1)] for j in range(0,3)] for i in range(0,3)]
    
    for i in range(0,3):
        H[i][0][0][0,:,:] = 2*X[i][0,:,:]-5*X[i][1,:,:]+4*X[i][2,:,:]-X[i][3,:,:]
        H[i][0][0][-1,:,:] = 2*X[i][-1,:,:]-5*X[i][-2,:,:]+4*X[i][-3,:,:]-X[i][-4,:,:]
        H[i][1][1][:,0,:] = 2*X[i][:,0,:]-5*X[i][:,1,:]+4*X[i][:,2,:]-X[i][:,3,:]
        H[i][1][1][:,-1,:] = 2*X[i][:,-1,:]-5*X[i][:,-2,:]+4*X[i][:,-3,:]-X[i][:,-4,:]
        H[i][2][2][:,:,0] = 2*X[i][:,:,0]-5*X[i][:,:,1]+4*X[i][:,:,2]-X[i][:,:,3]
        H[i][2][2][:,:,-1] = 2*X[i][:,:,-1]-5*X[i][:,:,-2]+4*X[i][:,:,-3]-X[i][:,:,-4]
        
        for j in (1,2):
            H[i][j][0][0,:,:] = -1.5*J[i][j][0,:,:]+2*J[i][j][1,:,:]-0.5*J[i][j][2,:,:]
            H[i][j][0][-1,:,:] = 1.5*J[i][j][-1,:,:]-2*J[i][j][-2,:,:]+0.5*J[i][j][-3,:,:]
        
        H[i][2][1][:,0,:] = -1.5*J[i][2][:,0,:]+2*J[i][2][:,1,:]-0.5*J[i][2][:,2,:]
        H[i][2][1][:,-1,:] = 1.5*J[i][2][:,-1,:]-2*J[i][2][:,-2,:]+0.5*J[i][2][:,-3,:]        
    
    return (H, J)       

def det(a):
    return np.sum([a[0][i-1]*(a[1][i]*a[2][i+1]-a[1][i+1]*a[2][i]) for i in [1,-1,0]],0)

def rot(B, X):
    hes = hessian(X)
    J = hes[1]
    H = hes[0]
    detJ = det(J)
    Jb = [[(J[i][j]*J[i+1][j+1] - J[i+1][j]*J[i][j+1])/detJ for j in [-2,-1,0]] for i in [1,-1,0]]
    dB = [np.gradient(B[i], edge_order = 2) for i in range(0,3)]
    Bx = [np.sum([J[i][j]*B[j] for j in range(0,3)],0)/detJ for i in range(0,3)]
    
    #B2 = np.sum(np.power(B,2),0)
    #Bx2 = np.sum(np.power(Bx,2),0)
  
    #DdetJ = [det([[H[i][j][0],J[i][1],J[i][2]] for i in range(0,3)])+
    #        det([[J[i][0],H[i][max(j,1)][min(j,1)],J[i][2]] for i in range(0,3)])+
    #        det([[J[i][0],J[i][1],H[i][max(j,2)][min(j,2)]] for i in range(0,3)]) for j in range(0,3)]

    DdetJ = [np.sum([[H[i][max(j,k)][min(j,k)]*Jb[i][j] for i in range(0,3)] for j in range(0,3)],(0,1))*detJ for k in range(0,3)]    

    
    dBx = [[(np.sum([J[i][k]*dB[k][j] + H[i][max(k,j)][min(k,j)]*B[k] for k in range(0,3)],0) -
                DdetJ[j]*Bx[i])/detJ for j in range(0,3)] for i in range(0,3)]
    
    #rotB = [np.sum([Jb[i][j]*dBx[i+1][j]-Jb[i+1][j]*dBx[i][j] for j in range(0,3)],0) for i in [1,-1,0]]
    
    force = [np.sum([B[j]*dBx[i][j]/detJ - np.sum([Bx[k]*dBx[k][j] for k in range(0,3)],0)*Jb[i][j]
                     for j in range(0,3)],0) for i in range(0,3)]
    
    #b = [np.sum([B[j]*dBx[i][j]/detJ for j in range(0,3)],0) for i in range(0,3)]
    #c = [np.sum([Bx[j]*dBx[j][i] for j in range(0,3)],0)  for i in range(0,3)]
    
    
    #q = [np.sum([(B2/detJ**2*(i == j) - Bx[i]*np.sum([Jb[k][j]*B[k] for k in range(0,3)],0)/detJ - 
    #      Bx[j]*np.sum([Jb[k][i]*B[k] for k in range(0,3)],0)/detJ + 
    #      Bx2*np.sum([Jb[k][i]*Jb[k][j] for k in range(0,3)],0))*X[j]
    #      for j in range(0,3)],0) for i in range(0,3)]
    
    return force

def force(B, X):
    ## from Craig & Sneyd (1986)
    dB = [np.gradient(B[i], edge_order = 2) for i in range(0,3)]
    hes = hessian(X)
    J = hes[1]
    H = hes[0]
    detJ = det(J)
    detJ2 = detJ**2
    Jb = [[(J[i][j]*J[i+1][j+1] - J[i+1][j]*J[i][j+1])/detJ for j in [-2,-1,0]] for i in [1,-1,0]]
    b = [np.sum([J[i][j]*B[j] for j in range(0,3)],0) for i in range(0,3)]
    b2 = np.sum(np.power(b,2),0)
    g = [[1 if i==j else 0 for j in range(0,3)] for i in range(0,3)]
    
    A = [[[[(g[i][j]*B[k]*B[l] - (b[i]*Jb[j][k]+b[j]*Jb[i][k])*B[l] + b2*Jb[l][i]*Jb[j][k])/detJ2
            for l in range(0,3)] for k in range(0,3)] for j in range(0,3)] for i in range(0,3)]
    
    C = [(np.sum([np.sum([B[k]*dB[j][k] for k in range(0,3)],0)*J[i][j] for j in range(0,3)],0) -
         np.sum([np.sum([np.sum([J[k][l]*dB[l][j] for l in range(0,3)],0)*b[k] for k in range(0,3)],0)*Jb[i][j]
                 for j in range(0,3)],0))/detJ2
         for i in range(0,3)]
    
    return [np.sum([np.sum([np.sum([A[i][j][k][l]*H[j][max(k,l)][min(k,l)] for l in range(0,3)],0)
                            for k in range(0,3)],0) for j in range(0,3)],0) + C[i] for i in range(0,3)]

# %%
dim = [64,64,24]
X = np.mgrid[0:dim[0], 0:dim[1], 0:dim[2]].astype(np.float64)
xsh = X.shape
B = [np.zeros(dim) for i in range(0,3)]
B[2] = np.ones(dim)
X1 = np.array(X)
ar = 4**2
az = 8
h = np.exp(-((X[0]-dim[0]/2)**2 + (X[1]-dim[1]/2)**2)/ar - X[2]/az)*np.pi/2

#h = np.exp(-((X[0]-dim[0]/2)**2 + (X[1]-dim[1]/2)**2)/ar)*X[2]/dim[2]*np.pi/4

X[0] = (X1[0]-dim[0]/2)*np.cos(h) - (X1[1]-dim[1]/2)*np.sin(h) + dim[0]/2
X[1] = (X1[0]-dim[0]/2)*np.sin(h) + (X1[1]-dim[1]/2)*np.cos(h) + dim[1]/2


#X[0][20:40,20:40,0] = X[0][20:40,20:40,0] + np.random.rand(20,20)*0.9
#X[1][20:40,20:40,0] = X[1][20:40,20:40,0] + np.random.rand(20,20)*0.9

#X[1] = X[1] + (X[0]-dim[0]/2)*np.exp(-np.abs(X[0]-dim[0]/2)/2)*np.cos(np.pi*X[2]/dim[2])

X1 = np.array(X)

F = np.array(rot(B,X))

plt.imshow(F[2][:,:,0])

# %%
def f(t,y):
    y.shape = xsh
    f = np.array(rot(B,y))*1e-2
    f[:,:,:,0] = 0
    f[:,:,:,-1] = 0
    return f.flatten()

r = ode(f).set_integrator('dop853').set_initial_value(X1.flatten(),0)

dt = 1

while r.t < 1000 and r.successful():
    Y = np.array(r.integrate(r.t+dt))
    Y.shape = xsh
    
    fig = plt.figure(0,[8,8])
    ax = fig.add_subplot(111, projection='3d')
    for i in range(24,40,2):
        for j in range(24,40,2):
            ax.plot(Y[0][i,j,:],Y[1][i,j,:],Y[2][i,j,:], color = 'green')
    plt.savefig('img/img'+str(np.floor(r.t).astype(np.int32)))
    
    print r.t, np.max(np.abs(rot(B,Y)))
# Out:
# 1.0 0.99458055309
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2be94abfa61a> in <module>()
#      13
#      14 while r.t < 1000 and r.successful():
# ---> 15     Y = np.array(r.integrate(r.t+dt))
#      16     Y.shape = xsh
#      17
#
# C:\Anaconda\lib\site-packages\scipy\integrate\_ode.py in integrate(self, t, step, relax)
#     392             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     393                                 self._y, self.t, t,
# --> 394                                 self.f_params, self.jac_params)
#     395         except SystemError:
#     396             # f2py issue with tuple returns, see ticket 1187.
#
# C:\Anaconda\lib\site-packages\scipy\integrate\_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1014     def run(self, f, jac, y0, t0, t1, f_params, jac_params):
#    1015         x, y, iwork, idid = self.runner(*((f, t0, y0, t1) +
# -> 1016                                           tuple(self.call_args) + (f_params,)))
#    1017         if idid < 0:
#    1018             warnings.warn(self.name + ': ' +
#
# <ipython-input-7-2be94abfa61a> in f(t, y)
#       3 def f(t,y):
#       4     y.shape = xsh
# ----> 5     f = np.array(rot(B,y))*1e-2
#       6     f[:,:,:,0] = 0
#       7     f[:,:,:,-1] = 0
#
# <ipython-input-5-46d37e58e001> in rot(B, X)
#      45     detJ = det(J)
#      46     Jb = [[(J[i][j]*J[i+1][j+1] - J[i+1][j]*J[i][j+1])/detJ for j in [-2,-1,0]] for i in [1,-1,0]]
# ---> 47     dB = [np.gradient(B[i], edge_order = 2) for i in range(0,3)]
#      48     Bx = [np.sum([J[i][j]*B[j] for j in range(0,3)],0)/detJ for i in range(0,3)]
#      49
#
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.pyc in gradient(f, *varargs, **kwargs)
#    1038
#    1039         # divide by step size
# -> 1040         out /= dx[axis]
#    1041         outvals.append(out)
#    1042
#
# KeyboardInterrupt:

# %%
X = np.array(X1)

step = 0.025
for i in range(0,1000):
    F1 = np.array(rot(B,X))
    F1[:,:,:,0] = 0
    F1[:,:,:,-1] = 0
    F2 = np.array(rot(B,X+F1*step*0.5))
    F2[:,:,:,0] = 0
    F2[:,:,:,-1] = 0
    F3 = np.array(rot(B,X+F2*step*0.5))
    F3[:,:,:,0] = 0
    F3[:,:,:,-1] = 0
    F4 = np.array(rot(B,X+F3*step))
    F4[:,:,:,0] = 0
    F4[:,:,:,-1] = 0
    
    F = (F1+2*F2+2*F3+F4)/6
    #F[:,:,:,0] = 0
    #F[:,:,:,-1] = 0
    X += F*step
    print np.max(np.abs(F))
# Out:
# 0.0601235232564
# 0.0568387371951
# 0.0537599971978
# 0.0508743144064
# 0.0481693306192
# 0.0456333310968
# 0.0432552465547
# 0.0410246465645
# 0.0391657798412
# 0.0380704882702
# 0.0372477868961
# 0.036432650882
# 0.0356265472217
# 0.0348307230111
# 0.0340462310798
# 0.033273952598
# 0.0325146170459
# 0.0320110777197
# 0.0316172235203
# 0.0312227985861
# 0.0308285335924
# 0.0304350812454
# 0.0300430236145
# 0.0296528787607
# 0.0292651067307
# 0.0288801149796
# 0.0284982632797
# 0.0281198681652
# 0.0277452069616
# 0.0273745214385
# 0.0270080211253
# 0.026645886321
# 0.0262882708303
# 0.0259353044496
# 0.0255870952306
# 0.0252437315391
# 0.0249052839308
# 0.0245718068608
# 0.024243340241
# 0.0239199108611
# 0.0236015336845
# 0.0232882130308
# 0.0230375770034
# 0.0228363441298
# 0.0226361845084
# 0.0224371801799
# 0.0222394073192
# 0.0220429364751
# 0.021847832808
# 0.021654156324
# 0.0214619621044
# 0.0212713005312
# 0.0210822175074
# 0.0208947546714
# 0.0207089496068
# 0.0205248360451
# 0.0203424440634
# 0.0201618002749
# 0.0199829280142
# 0.0198058475149
# 0.0196305760822
# 0.0194571282582
# 0.0192855159807
# 0.019115748737
# 0.0189478337096
# 0.0187817759175
# 0.0186175783506
# 0.0184552420979
# 0.0182947664711
# 0.0181361491216
# 0.0179793861522
# 0.0178244722239
# 0.0176714006571
# 0.0175201635282
# 0.0173707517609
# 0.0172231552136
# 0.0170773627615
# 0.00846388041606
# 0.00845631808532
# 0.00844875939473
# 0.00844120441671
# 0.0084336532227
# 0.00842610588317
# 0.0084185624677
# 0.00841102304491
# 0.00840348768251
# 0.00839595644733
# 0.00838842940525
# 0.00838090662127
# 0.00837338815956
# 0.00836587408337
# 0.00835836445508
# 0.00835085933626
# 0.0083433587876
# 0.008335862869
# 0.00832837163945
# 0.0083208851572
# 0.00831340347968
# 0.00830592666351
# 0.00829845476448
# 0.00829098783766
# 0.00828352593731
# 0.00827606911693
# 0.00826861742924
# 0.00826117092625
# 0.0082537296592
# 0.00824629367863
# 0.00823886303429
# 0.00823143777524
# 0.00822401794986
# 0.00821660360582
# 0.00820919479006
# 0.00820179154882
# 0.00819439392772
# 0.00818700197165
# 0.0081796157249
# 0.00817223523102
# 0.00816486053297
# 0.00815749167302
# 0.00815012869286
# 0.00814277163349
# 0.00813542053529
# 0.00812807543807
# 0.008120736381
# 0.00811340340266
# 0.00810607654098
# 0.00809875583337
# 0.00809144131665
# 0.008084133027
# 0.00807683100008
# 0.00806953527099
# 0.00806224587424
# 0.00805496284381
# 0.00804768621311
# 0.00804041601503
# 0.00803315228194
# 0.00802589504564
# 0.00801864433744
# 0.00801140018813
# 0.00800416262796
# 0.00799693168671
# 0.00798970739364
# 0.00798248977754
# 0.00797527886668
# 0.00796807468885
# 0.0079608772714
# 0.00795368664116
# 0.00794650282453
# 0.00793932584741
# 0.00793215573527
# 0.00792499251313
# 0.00791783620555
# 0.00791068683669
# 0.00790354443018
# 0.00789640900932
# 0.00788928059691
# 0.00788215921537
# 0.0078750448867
# 0.00786793763248
# 0.00786083747387
# 0.00785374443166
# 0.0078466585262
# 0.00783957977747
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4a6fb7ced9a4> in <module>()
#       6     F1[:,:,:,0] = 0
#       7     F1[:,:,:,-1] = 0
# ----> 8     F2 = np.array(rot(B,X+F1*step*0.5))
#       9     F2[:,:,:,0] = 0
#      10     F2[:,:,:,-1] = 0
#
# <ipython-input-3-8f7c0dfd6d62> in rot(B, X)
#      55     #        det([[J[i][0],J[i][1],H[i][max(j,2)][min(j,2)]] for i in range(0,3)]) for j in range(0,3)]
#      56
# ---> 57     DdetJ = [np.sum([[H[i][max(j,k)][min(j,k)]*Jb[i][j] for i in range(0,3)] for j in range(0,3)],(0,1))*detJ for k in range(0,3)]
#      58
#      59
#
# KeyboardInterrupt:

# %%
# %matplotlib inline

fig = plt.figure(0,[8,8])
ax = fig.add_subplot(111, projection='3d')
for i in range(24,40,2):
    for j in range(24,40,2):
        ax.plot(X[0][i,j,:],X[1][i,j,:],X[2][i,j,:], color = 'green')
plt.show()

# %%
# %matplotlib inline

fig = plt.figure(0,[8,8])
ax = fig.add_subplot(111, projection='3d')
for i in range(24,40,2):
    for j in range(24,40,2):
        ax.plot(X1[0][i,j,:],X1[1][i,j,:],X1[2][i,j,:], color = 'green')
plt.show()

# %%
# %matplotlib inline
plt.imshow(X[2][:,:,1])

# %%
np.min(X[2][:,:,1])
# Out:
# -22034.555557331943
