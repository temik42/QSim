# %%
# %cd 'Q:\Dropbox\python\QSim\'
# Out:
# Q:\Dropbox\python\QSim

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import numpy.fft as fft

# %%
q = np.zeros(64)
q[16] = 1
q[48] = -1

x = np.arange(0,128)-64

r = x/(abs(x).clip(min=1))**3.



fr = fft.fft(r)


#q1 = fft.ifft(fq*(-1j))
plt.plot(fr*1j)
